# %% [markdown]
# # День 00 – Сбор данных

# %% [markdown]
# Добро пожаловать в Jupyter Notebook! Это тот инструмент, в котором дата сайентисты проводят больше всего времени, работая с данными при помощи кода на Python. Здесь очень удобно работать в интерактивном режиме, запуская отдельные ячейки, а не весь код сразу и полностью. Тут же можно делать и отчеты, поскольку помимо кода, здесь удобно строить графики и писать текст.

# %% [markdown]
# Мы понимаем, что вы не программисты и скорее всего не планируете ими стать, поэтому насколько это возможно мы будем сопровождать такие ноутбуки комментариями и полезными командами, которые могут вам пригодиться для решения задачи. Но естественно здесь будет не всё: что-то вам придется поискать самостоятельно в интернете. Такова уж методология Школы 21, и она приносит свои плоды.

# %% [markdown]
# ## 0. Импорт библиотек

# %% [markdown]
# Библиотека – это по сути набор полезных функций и методов, которые написали одни программисты, а другие программисты могут уже не писать их с нуля, а пользоваться готовыми. Например, вы хотите посчитать среднее арифметическое значение по ряду. Вы можете самостоятельно написать код, который посчитает сумму по ряду и поделит на количество элементов в ряду, а можете импортировать библиотеку, где уже есть эта функция и воспользоваться ею. Это сэкономит вам время, силы, и код будет менее объемным.
#
# Ниже мы импортируем широко используемую библиотеку Pandas. В ней есть много полезных функций для работы с табличными данными. Почти Excel, только взаимодействие с ним через код на Python. Мы будем пользоваться этой библиотекой в течение всего курса.

# %%
import pandas as pd #мы будем часто пользоваться методами этой библиотеки, поэтому введем для нее сокращенное название – pd

# %% [markdown]
# ## 1. Загрузка данных

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df1 = pd.read_csv('/content/drive/MyDrive/School21/day00/part_01.csv') #указываем путь к файлу
df1.head() #посмотрим несколько первых строк получившегося датафрейма
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-ef761ceac99f> in <module>
# ----> 1 df1 = pd.read_csv('/content/drive/MyDrive/School21/day00/part_01.csv') #указываем путь к файлу
#       2 df1.head() #посмотрим несколько первых строк получившегося датафрейма
#
# NameError: name 'pd' is not defined

# %% [markdown]
# Если всё получилось, то вы увидите небольшой кусок таблицы: шапку, первые пять строчек и часть столбцов (несколько первых и несколько последних).

# %% [markdown]
# ## 2. Полезные команды

# %% [markdown]
# Ниже мы покажем несколько полезных команд, которые вам могут пригодиться для выполнения сегодняшнего задания.

# %% [markdown]
# 1. Узнать **названия полей** в датафрейме.

# %%
df1.columns
# Out:
# Index(['ID', 'AMOUNT_RUB_ATM_PRC', 'AMOUNT_RUB_CLO_PRC', 'AMOUNT_RUB_NAS_PRC',
#        'AMOUNT_RUB_SUP_PRC', 'CNT_TRAN_ATM_TENDENCY1M',
#        'CNT_TRAN_ATM_TENDENCY3M', 'CNT_TRAN_AUT_TENDENCY1M',
#        'CNT_TRAN_AUT_TENDENCY3M', 'CNT_TRAN_CLO_TENDENCY1M',
#        'CNT_TRAN_CLO_TENDENCY3M', 'CNT_TRAN_MED_TENDENCY1M',
#        'CNT_TRAN_MED_TENDENCY3M', 'CNT_TRAN_SUP_TENDENCY1M',
#        'CNT_TRAN_SUP_TENDENCY3M', 'SUM_TRAN_ATM_TENDENCY1M',
#        'SUM_TRAN_ATM_TENDENCY3M', 'SUM_TRAN_AUT_TENDENCY1M',
#        'SUM_TRAN_AUT_TENDENCY3M', 'SUM_TRAN_CLO_TENDENCY1M',
#        'SUM_TRAN_CLO_TENDENCY3M', 'SUM_TRAN_MED_TENDENCY1M',
#        'SUM_TRAN_MED_TENDENCY3M', 'SUM_TRAN_SUP_TENDENCY1M',
#        'SUM_TRAN_SUP_TENDENCY3M', 'TRANS_AMOUNT_TENDENCY3M',
#        'TRANS_CNT_TENDENCY3M', 'TRANS_COUNT_ATM_PRC', 'TRANS_COUNT_NAS_PRC',
#        'TRANS_COUNT_SUP_PRC'],
#       dtype='object')

# %% [markdown]
# 2. Присоединить датафрейм **снизу**:

# %%
new_df = pd.concat([df1, df1])
new_df
# Out:
#             ID  AMOUNT_RUB_ATM_PRC  AMOUNT_RUB_CLO_PRC  AMOUNT_RUB_NAS_PRC  \
# 0       199360            1.000000            0.000000            0.000000
# 1       285903            0.548968            0.006725            0.000000
# 2       259249            0.060149            0.000000            0.000000
# 3       447959            0.096392            0.363477            0.009300
# 4       196498            0.881967            0.050398            0.000000
# ...        ...                 ...                 ...                 ...
# 177590  496698            1.000000            0.000000            0.000000
# 177591  383782            0.740151            0.126350            0.000000
# 177592  175289            0.999661            0.000000            0.000000
# 177593  467697            0.852134            0.000000            0.000000
# 177594  548533            0.000000            0.000000            0.725952
#
#         AMOUNT_RUB_SUP_PRC  CNT_TRAN_ATM_TENDENCY1M  CNT_TRAN_ATM_TENDENCY3M  \
# 0                 0.000000                 0.250000                 0.750000
# 1                 0.102824                 0.025000                 0.650000
# 2                 0.615370                      NaN                      NaN
# 3                 0.136140                 0.166667                 0.500000
# 4                 0.062595                 0.142857                 0.142857
# ...                    ...                      ...                      ...
# 177590            0.000000                 0.400000                 0.800000
# 177591            0.026732                 0.406250                 1.000000
# 177592            0.000000                 0.200000                 0.300000
# 177593            0.068945                 0.281250                 0.875000
# 177594            0.000000                      NaN                      NaN
#
#         CNT_TRAN_AUT_TENDENCY1M  CNT_TRAN_AUT_TENDENCY3M  \
# 0                           NaN                      NaN
# 1                           NaN                 0.666667
# 2                           1.0                 1.000000
# 3                           NaN                      NaN
# 4                           NaN                      NaN
# ...                         ...                      ...
# 177590                      NaN                      NaN
# 177591                      1.0                 1.000000
# 177592                      NaN                      NaN
# 177593                      1.0                 1.000000
# 177594                      NaN                      NaN
#
#         CNT_TRAN_CLO_TENDENCY1M  ...  SUM_TRAN_CLO_TENDENCY3M  \
# 0                           NaN  ...                      NaN
# 1                           NaN  ...                      NaN
# 2                           NaN  ...                      NaN
# 3                      0.090909  ...                 0.452527
# 4                           NaN  ...                      NaN
# ...                         ...  ...                      ...
# 177590                      NaN  ...                      NaN
# 177591                 0.545455  ...                 1.000000
# 177592                      NaN  ...                      NaN
# 177593                      NaN  ...                      NaN
# 177594                      NaN  ...                      NaN
#
#         SUM_TRAN_MED_TENDENCY1M  SUM_TRAN_MED_TENDENCY3M  \
# 0                           NaN                      NaN
# 1                      0.023043                 0.365189
# 2                           NaN                      NaN
# 3                           NaN                 0.130446
# 4                           NaN                      NaN
# ...                         ...                      ...
# 177590                      NaN                      NaN
# 177591                      NaN                 1.000000
# 177592                      NaN                      NaN
# 177593                 0.322581                 0.881720
# 177594                      NaN                      NaN
#
#         SUM_TRAN_SUP_TENDENCY1M  SUM_TRAN_SUP_TENDENCY3M  \
# 0                           NaN                      NaN
# 1                           NaN                 0.368032
# 2                           NaN                 1.000000
# 3                      0.116332                 0.351140
# 4                           NaN                      NaN
# ...                         ...                      ...
# 177590                      NaN                      NaN
# 177591                 0.345832                 1.000000
# 177592                      NaN                      NaN
# 177593                 0.232570                 0.859741
# 177594                      NaN                      NaN
#
#         TRANS_AMOUNT_TENDENCY3M  TRANS_CNT_TENDENCY3M  TRANS_COUNT_ATM_PRC  \
# 0                      0.744186              0.750000             1.000000
# 1                      0.486163              0.511628             0.232558
# 2                      0.939851              0.875000             0.125000
# 3                      0.435642              0.418803             0.051282
# 4                      0.105836              0.153846             0.538462
# ...                         ...                   ...                  ...
# 177590                 0.983819              0.800000             1.000000
# 177591                 1.000000              1.000000             0.405063
# 177592                 0.400542              0.272727             0.909091
# 177593                 0.784559              0.863248             0.273504
# 177594                 0.410905              0.377193             0.000000
#
#         TRANS_COUNT_NAS_PRC  TRANS_COUNT_SUP_PRC
# 0                  0.000000             0.000000
# 1                  0.000000             0.052326
# 2                  0.000000             0.125000
# 3                  0.008547             0.179487
# 4                  0.000000             0.307692
# ...                     ...                  ...
# 177590             0.000000             0.000000
# 177591             0.000000             0.189873
# 177592             0.000000             0.000000
# 177593             0.000000             0.444444
# 177594             0.763158             0.000000
#
# [355190 rows x 30 columns]

# %% [markdown]
# 3. Присоединить датафрейм **справа**:

# %%
df1.merge(df1, left_on='ID', right_on='ID') # выбираем ID в качестве ключа, по которому датафреймы будут объединяться
# Out:
#             ID  AMOUNT_RUB_ATM_PRC_x  AMOUNT_RUB_CLO_PRC_x  \
# 0       199360              1.000000              0.000000
# 1       285903              0.548968              0.006725
# 2       259249              0.060149              0.000000
# 3       447959              0.096392              0.363477
# 4       196498              0.881967              0.050398
# ...        ...                   ...                   ...
# 177590  496698              1.000000              0.000000
# 177591  383782              0.740151              0.126350
# 177592  175289              0.999661              0.000000
# 177593  467697              0.852134              0.000000
# 177594  548533              0.000000              0.000000
#
#         AMOUNT_RUB_NAS_PRC_x  AMOUNT_RUB_SUP_PRC_x  CNT_TRAN_ATM_TENDENCY1M_x  \
# 0                   0.000000              0.000000                   0.250000
# 1                   0.000000              0.102824                   0.025000
# 2                   0.000000              0.615370                        NaN
# 3                   0.009300              0.136140                   0.166667
# 4                   0.000000              0.062595                   0.142857
# ...                      ...                   ...                        ...
# 177590              0.000000              0.000000                   0.400000
# 177591              0.000000              0.026732                   0.406250
# 177592              0.000000              0.000000                   0.200000
# 177593              0.000000              0.068945                   0.281250
# 177594              0.725952              0.000000                        NaN
#
#         CNT_TRAN_ATM_TENDENCY3M_x  CNT_TRAN_AUT_TENDENCY1M_x  \
# 0                        0.750000                        NaN
# 1                        0.650000                        NaN
# 2                             NaN                        1.0
# 3                        0.500000                        NaN
# 4                        0.142857                        NaN
# ...                           ...                        ...
# 177590                   0.800000                        NaN
# 177591                   1.000000                        1.0
# 177592                   0.300000                        NaN
# 177593                   0.875000                        1.0
# 177594                        NaN                        NaN
#
#         CNT_TRAN_AUT_TENDENCY3M_x  CNT_TRAN_CLO_TENDENCY1M_x  ...  \
# 0                             NaN                        NaN  ...
# 1                        0.666667                        NaN  ...
# 2                        1.000000                        NaN  ...
# 3                             NaN                   0.090909  ...
# 4                             NaN                        NaN  ...
# ...                           ...                        ...  ...
# 177590                        NaN                        NaN  ...
# 177591                   1.000000                   0.545455  ...
# 177592                        NaN                        NaN  ...
# 177593                   1.000000                        NaN  ...
# 177594                        NaN                        NaN  ...
#
#         SUM_TRAN_CLO_TENDENCY3M_y  SUM_TRAN_MED_TENDENCY1M_y  \
# 0                             NaN                        NaN
# 1                             NaN                   0.023043
# 2                             NaN                        NaN
# 3                        0.452527                        NaN
# 4                             NaN                        NaN
# ...                           ...                        ...
# 177590                        NaN                        NaN
# 177591                   1.000000                        NaN
# 177592                        NaN                        NaN
# 177593                        NaN                   0.322581
# 177594                        NaN                        NaN
#
#         SUM_TRAN_MED_TENDENCY3M_y  SUM_TRAN_SUP_TENDENCY1M_y  \
# 0                             NaN                        NaN
# 1                        0.365189                        NaN
# 2                             NaN                        NaN
# 3                        0.130446                   0.116332
# 4                             NaN                        NaN
# ...                           ...                        ...
# 177590                        NaN                        NaN
# 177591                   1.000000                   0.345832
# 177592                        NaN                        NaN
# 177593                   0.881720                   0.232570
# 177594                        NaN                        NaN
#
#         SUM_TRAN_SUP_TENDENCY3M_y  TRANS_AMOUNT_TENDENCY3M_y  \
# 0                             NaN                   0.744186
# 1                        0.368032                   0.486163
# 2                        1.000000                   0.939851
# 3                        0.351140                   0.435642
# 4                             NaN                   0.105836
# ...                           ...                        ...
# 177590                        NaN                   0.983819
# 177591                   1.000000                   1.000000
# 177592                        NaN                   0.400542
# 177593                   0.859741                   0.784559
# 177594                        NaN                   0.410905
#
#         TRANS_CNT_TENDENCY3M_y  TRANS_COUNT_ATM_PRC_y  TRANS_COUNT_NAS_PRC_y  \
# 0                     0.750000               1.000000               0.000000
# 1                     0.511628               0.232558               0.000000
# 2                     0.875000               0.125000               0.000000
# 3                     0.418803               0.051282               0.008547
# 4                     0.153846               0.538462               0.000000
# ...                        ...                    ...                    ...
# 177590                0.800000               1.000000               0.000000
# 177591                1.000000               0.405063               0.000000
# 177592                0.272727               0.909091               0.000000
# 177593                0.863248               0.273504               0.000000
# 177594                0.377193               0.000000               0.763158
#
#         TRANS_COUNT_SUP_PRC_y
# 0                    0.000000
# 1                    0.052326
# 2                    0.125000
# 3                    0.179487
# 4                    0.307692
# ...                       ...
# 177590               0.000000
# 177591               0.189873
# 177592               0.000000
# 177593               0.444444
# 177594               0.000000
#
# [177595 rows x 59 columns]

# %% [markdown]
# Если вам не хватает команд, представленных в этом ноутбуке, то вы можете **самостоятельно воспользоваться поиском в Google**.
#
#     "pandas how to save a csv-file with header"

# %% [markdown]
# ## 3. Самостоятельная часть

# %% [markdown]
# Ниже вам нужно самим собрать целиком датасет из разрозненных кусков.

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df1 = pd.read_csv('/content/drive/MyDrive/School21/day00/part_01.csv')
df2 = pd.read_csv('/content/drive/MyDrive/School21/day00/part_02.csv')
df3 = pd.read_csv('/content/drive/MyDrive/School21/day00/part_03.csv')
df4 = pd.read_csv('/content/drive/MyDrive/School21/day00/part_04.csv')
df5 = pd.read_csv('/content/drive/MyDrive/School21/day00/part_05.csv')
df6 = pd.read_csv('/content/drive/MyDrive/School21/day00/part_06.csv')
df7 = pd.read_csv('/content/drive/MyDrive/School21/day00/part_07.csv')
df8 = pd.read_csv('/content/drive/MyDrive/School21/day00/part_08.csv')
df9 = pd.read_csv('/content/drive/MyDrive/School21/day00/part_09.csv')
df10 = pd.read_csv('/content/drive/MyDrive/School21/day00/part_10.csv')
df11 = pd.read_csv('/content/drive/MyDrive/School21/day00/part_11.csv')
df12 = pd.read_csv('/content/drive/MyDrive/School21/day00/part_12.csv')

# %%
 df2.columns == df11.columns
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True])

# %%
df1.columns == df9.columns
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True])

# %%
df2.columns == df11.columns
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True])

# %%
df3.columns == df8.columns
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True])

# %%
df4.columns == df7.columns
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True])

# %%
df5.columns == df12.columns
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True])

# %%
new_df13 = pd.concat([df1, df9])
new_df14 = pd.concat([df2, df11])
new_df15 = pd.concat([df3, df8])
new_df16 = pd.concat([df4, df7])
new_df17 = pd.concat([df5, df12])
new_df18 = pd.concat([df6, df10])

# %%
d00_result = new_df13.merge(new_df14, on='ID')\
.merge(new_df15, on='ID')\
.merge(new_df16, on='ID')\
.merge(new_df17, on='ID')\
.merge(new_df18, on='ID')\
.sort_values('ID')
d00_result
# Out:
#             ID  AMOUNT_RUB_ATM_PRC  AMOUNT_RUB_CLO_PRC  AMOUNT_RUB_NAS_PRC  \
# 236790  146841            1.000000            0.000000            0.000000
# 196597  146842            0.410691            0.041033            0.000000
# 243652  146843            0.925140            0.006915            0.000000
# 22845   146844            1.000000            0.000000            0.000000
# 195106  146845            1.000000            0.000000            0.000000
# ...        ...                 ...                 ...                 ...
# 218938  590822            0.786104            0.000000            0.000000
# 57934   590823            0.000000            0.000000            0.262714
# 81873   590825            0.000000            0.041298            0.031179
# 237919  590826            0.717427            0.000000            0.282573
# 14588   590828            1.000000            0.000000            0.000000
#
#         AMOUNT_RUB_SUP_PRC  CNT_TRAN_ATM_TENDENCY1M  CNT_TRAN_ATM_TENDENCY3M  \
# 236790            0.000000                 0.101695                 0.406780
# 196597            0.244678                 0.166667                 0.333333
# 243652            0.000000                 0.133333                 0.366667
# 22845             0.000000                      NaN                      NaN
# 195106            0.000000                 0.172414                 0.620690
# ...                    ...                      ...                      ...
# 218938            0.000000                      NaN                 0.500000
# 57934             0.000000                      NaN                      NaN
# 81873             0.095187                      NaN                      NaN
# 237919            0.000000                 0.250000                 1.000000
# 14588             0.000000                      NaN                      NaN
#
#         CNT_TRAN_AUT_TENDENCY1M  CNT_TRAN_AUT_TENDENCY3M  \
# 236790                      NaN                      NaN
# 196597                 0.166667                 0.666667
# 243652                      NaN                      NaN
# 22845                       NaN                      NaN
# 195106                      NaN                      NaN
# ...                         ...                      ...
# 218938                 0.142857                 1.000000
# 57934                       NaN                      NaN
# 81873                  0.089286                 0.392857
# 237919                      NaN                      NaN
# 14588                       NaN                      NaN
#
#         CNT_TRAN_CLO_TENDENCY1M  ...  TURNOVER_CC  TURNOVER_DYNAMIC_CC_1M  \
# 236790                      NaN  ...          0.0                     0.0
# 196597                      NaN  ...          0.0                     0.0
# 243652                      NaN  ...          0.0                     0.0
# 22845                       NaN  ...          0.0                     0.0
# 195106                      NaN  ...          0.0                     0.0
# ...                         ...  ...          ...                     ...
# 218938                      NaN  ...          0.0                     0.0
# 57934                       NaN  ...          0.0                     0.0
# 81873                       NaN  ...          0.0                     0.0
# 237919                      NaN  ...          0.0                     0.0
# 14588                       NaN  ...          0.0                     0.0
#
#         TURNOVER_DYNAMIC_CC_3M  TURNOVER_DYNAMIC_CUR_1M  \
# 236790                     0.0                 0.131910
# 196597                     0.0                 0.101934
# 243652                     0.0                 0.121041
# 22845                      0.0                 0.000005
# 195106                     0.0                 0.177869
# ...                        ...                      ...
# 218938                     0.0                 0.119700
# 57934                      0.0                 0.165218
# 81873                      0.0                 0.053596
# 237919                     0.0                 0.379720
# 14588                      0.0                 0.262351
#
#         TURNOVER_DYNAMIC_CUR_3M  TURNOVER_DYNAMIC_IL_1M  \
# 236790                 0.442285                     0.0
# 196597                 0.515876                     0.0
# 243652                 0.522833                     0.0
# 22845                  0.000189                     0.0
# 195106                 0.593648                     0.0
# ...                         ...                     ...
# 218938                 0.572322                     0.0
# 57934                  0.392381                     0.0
# 81873                  0.447377                     0.0
# 237919                 1.000000                     0.0
# 14588                  0.263319                     0.0
#
#         TURNOVER_DYNAMIC_IL_3M  TURNOVER_DYNAMIC_PAYM_1M  \
# 236790                     0.0                       0.0
# 196597                     0.0                       0.0
# 243652                     0.0                       0.0
# 22845                      0.0                       0.0
# 195106                     0.0                       0.0
# ...                        ...                       ...
# 218938                     0.0                       0.0
# 57934                      0.0                       0.0
# 81873                      0.0                       0.0
# 237919                     0.0                       0.0
# 14588                      0.0                       0.0
#
#         TURNOVER_DYNAMIC_PAYM_3M  TURNOVER_PAYM
# 236790                       0.0            0.0
# 196597                       0.0            0.0
# 243652                       0.0            0.0
# 22845                        0.0            0.0
# 195106                       0.0            0.0
# ...                          ...            ...
# 218938                       0.0            0.0
# 57934                        0.0            0.0
# 81873                        0.0            0.0
# 237919                       0.0            0.0
# 14588                        0.0            0.0
#
# [355190 rows x 116 columns]

# %%
d00_result.to_csv('d00_result.csv', sep=';', index_label='index')
